# %% [markdown]
# Question 1: What is Deep Learning? Briefly describe how it evolved and how it differs from traditional machine learning.
#
# Answer:
#
# Deep Learning is a subfield of Machine Learning that uses artificial neural networks with multiple hidden layers to automatically learn hierarchical representations from large amounts of data. It mimics the functioning of the human brain by processing information through interconnected neurons.
#
# Evolution of Deep Learning
#
# 1943 – McCulloch and Pitts proposed the first artificial neuron
#
# 1958 – Rosenblatt introduced the Perceptron
#
# 1980s – Backpropagation algorithm popularized
#
# 2010 onwards – Growth due to big data, GPUs, and advanced architectures like CNNs, RNNs, and Transformers
#
# Difference between Traditional ML and Deep Learning
# Aspect	             Traditional ML                         Deep Learning
# Feature Engineering	  Manual                                	Automatic
# Data Requirement	  Small to medium	                        Large datasets
# Model Complexity	 Simple algorithms	                    Deep neural networks
# Performance on        	Limited 	                            Excellent
# Images/Audio
# Interpretability	      Higher	                                Lower

# %% [markdown]
# Question 2: Explain the basic architecture and functioning of a Perceptron. What are its limitations?
#
# Answer:
#
# A Perceptron is the simplest form of an artificial neural network and is a binary linear classifier.
#
# Architecture
#
# Input layer (features)
#
# Weights for each input
#
# Bias term
#
# Summation unit
#
# Activation function (usually step function)
#
# Functioning
#
# The perceptron computes:
#
# 𝑦=
# 𝑓
# (
# ∑
# 𝑤
# 𝑖
# 𝑥
# 𝑖
# +
# 𝑏
# )
# y=f(∑w
# ixi+b)
#
# If the weighted sum exceeds a threshold, the output is 1; otherwise, 0.
#
# Limitations
#
# Can solve only linearly separable problems
#
# Cannot solve XOR problem
#
# No hidden layers
#
# Limited learning capacity

# %% [markdown]
# Question 3: Describe the purpose of activation function in neural networks. Compare Sigmoid, ReLU, and Tanh functions.
#
# Answer:
#
# Purpose of Activation Function
#
# Activation functions introduce non-linearity into neural networks, enabling them to learn complex patterns.
#
# ![Screenshot 2025-12-19 192017.png](data:image/png;base64,...)

# %% [markdown]
# Question 4: What is the difference between Loss function and Cost function in neural networks? Provide examples.
#
# Answer:
#
# Loss Function: Error for a single training example
#
# Cost Function: Average loss over the entire dataset
#
# Examples
#
# Loss: Mean Squared Error (MSE), Binary Cross-Entropy
#
# Cost: Average MSE across all samples

# %% [markdown]
# Question 5: What is the role of optimizers in neural networks? Compare Gradient Descent, Adam, and RMSprop.
#
# Answer:
#
# Optimizers update model parameters to minimize loss
# | Optimizer        | Description            | Pros               | Cons                         |
# | ---------------- | ---------------------- | ------------------ | ---------------------------- |
# | Gradient Descent | Uses full dataset      | Stable             | Slow                         |
# | RMSprop          | Adaptive learning rate | Faster convergence | Sensitive to hyperparameters |
# | Adam             | RMSprop + Momentum     | Fast, efficient    | May overfit                  |

# %%
# Question 6: Python program to implement a single-layer perceptron using NumPy for AND gate

import numpy as np

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])

weights = np.random.rand(2)
bias = 0
lr = 0.1

def step(x):
    return 1 if x >= 0 else 0

for epoch in range(10):
    for i in range(len(X)):
        linear = np.dot(X[i], weights) + bias
        y_pred = step(linear)
        error = y[i] - y_pred
        weights += lr * error * X[i]
        bias += lr * error

print("Weights:", weights)
print("Bias:", bias)
# Out:
# Weights: [0.43494322 0.56418539]
# Bias: -0.6

# %%
# Question 7: Implement and visualize Sigmoid, ReLU, and Tanh using Matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100)

sigmoid = 1/(1+np.exp(-x))
relu = np.maximum(0,x)
tanh = np.tanh(x)

plt.plot(x, sigmoid, label='Sigmoid')
plt.plot(x, relu, label='ReLU')
plt.plot(x, tanh, label='Tanh')
plt.legend()
plt.show()

# %%
# Question 8: Build and train a simple NN on MNIST using Keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

(X_train, y_train), _ = mnist.load_data()

X_train = X_train/255.0
y_train = to_categorical(y_train)

model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=5, batch_size=32)

print("Training Accuracy:", history.history['accuracy'][-1])
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8703 - loss: 0.4513
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9637 - loss: 0.1242
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9754 - loss: 0.0808
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9818 - loss: 0.0584
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9858 - loss: 0.0443
# Training Accuracy: 0.9850833415985107

# %%
# Question 9: Visualize loss and accuracy curves for Fashion MNIST and interpret
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['loss'], label='Loss')
plt.legend()
plt.show()

# %% [markdown]
# Question 10: Fraud Detection – Real-Time Data Science Workflow
# Model Design
#
# Use Multilayer Neural Network
#
# Input: transaction amount, merchant ID, location
#
# Hidden layers with ReLU
#
# Output layer with Sigmoid
#
# Activation & Loss
#
# Activation: ReLU (hidden), Sigmoid (output)
#
# Loss: Binary Cross-Entropy
#
# Handling Imbalanced Data
#
# Class weighting
#
# SMOTE
#
# Precision-Recall & ROC-AUC metrics
#
# Optimizer & Overfitting Prevention
#
# Optimizer: Adam
#
# Regularization (Dropout, L2)
#
# Early stopping
#
# Cross-validation

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
